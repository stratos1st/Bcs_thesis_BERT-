# %%
import sys
import argparse
# !pip uninstall -y tensorflow-gpu
# !pip uninstall -y tensorflow
# !pip install tensorflow==1.14.0
# !pip install tensorflow-gpu==1.14.0

# %%
# !wget https://storage.googleapis.com/bert_models/2018_11_03/multilingual_L-12_H-768_A-12.zip
# !unzip multilingual_L-12_H-768_A-12.zip

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python /content/drive/MyDrive/thesis/original_bert_repo/create_pretraining_data.py \
#   --input_file=/content/drive/MyDrive/thesis/dataset/raptarchis_for_pretraining_train.txt\
#   --output_file=/content/drive/MyDrive/thesis/dataset/raptarchis_for_pretraining.tfrecord \
#   --vocab_file=/content/drive/MyDrive/thesis/dataset/M_Bert_vocab.txt \
#   --do_lower_case=True \
#   --max_seq_length=512 \
#   --max_predictions_per_seq=77 \
#   --masked_lm_prob=0.15 \
#   --random_seed=12345 \
#   --dupe_factor=2

# %%
# !python /content/drive/MyDrive/thesis/original_bert_repo/run_pretraining.py \
  --input_file=/content/drive/MyDrive/thesis/dataset/raptarchis_for_pretraining.tfrecord \
  --output_dir=/content/drive/MyDrive/thesis/APT/M-Bert/ \
  --do_train=True \
  --do_eval=True \
  --bert_config_file=/content/multilingual_L-12_H-768_A-12/bert_config.json \
  --init_checkpoint=/content/multilingual_L-12_H-768_A-12/bert_model.ckpt \
  --train_batch_size=2 \
  --max_seq_length=512 \
  --max_predictions_per_seq=77 \
  --num_train_steps=12500 \
  --num_warmup_steps=0 \
  --learning_rate=2e-5 \
  --use_tpu=False \
  > /content/drive/MyDrive/thesis/APT/M-Bert/log.log
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
