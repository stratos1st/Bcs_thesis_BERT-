# %% [markdown]
# ###Dataset overlap
# just like in 'Don’t Stop Pretraining: Adapt Language Models to Domains and Tasks'. executed localy.

# %%
# code from https://github.com/allenai/dont-stop-pretraining slightly changed
from tqdm.notebook import tqdm
from sklearn.feature_extraction.text import CountVectorizer
import json
from itertools import combinations
import seaborn as sns
import numpy as np
# !pip install --upgrade matplotlib
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
from os.path import getsize
from glob import glob
from random import sample
import pandas as pd
from multiprocessing import Pool
# !pip3 install nltk
import nltk
nltk.download('stopwords')
import pickle
from string import digits


import sys
def i1():# helper function for fork printing
  sys.stdout.write(' ')
  sys.stdout.flush()

_remove_digits_func = str.maketrans('', '', digits)
_remove = True
# Out:
# Requirement already satisfied: matplotlib in ./jupyterenv/lib/python3.8/site-packages (3.4.3)
# Requirement already satisfied: cycler>=0.10 in ./jupyterenv/lib/python3.8/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in ./jupyterenv/lib/python3.8/site-packages (from matplotlib) (8.3.1)
# Requirement already satisfied: numpy>=1.16 in ./jupyterenv/lib/python3.8/site-packages (from matplotlib) (1.21.2)
# Requirement already satisfied: pyparsing>=2.2.1 in ./jupyterenv/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./jupyterenv/lib/python3.8/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./jupyterenv/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six in ./jupyterenv/lib/python3.8/site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Requirement already satisfied: nltk in ./jupyterenv/lib/python3.8/site-packages (3.6.2)
# Requirement already satisfied: joblib in ./jupyterenv/lib/python3.8/site-packages (from nltk) (1.0.1)
# Requirement already satisfied: regex in ./jupyterenv/lib/python3.8/site-packages (from nltk) (2021.8.21)
# Requirement already satisfied: click in ./jupyterenv/lib/python3.8/site-packages (from nltk) (8.0.1)
# Requirement already satisfied: tqdm in ./jupyterenv/lib/python3.8/site-packages (from nltk) (4.62.2)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_digits(text):
    if _remove:
      return text.translate(_remove_digits_func)
    else:
      return text

def read_file(fi, maxx=0):
  """ helper function for loading txts 
      if max!=0 it reads ~maxx bytes"""
  ans = []
  block_size = 2048
  total = 0
  with open(fi, 'rb') as f:
    def read_block():
      return f.read(block_size).decode(errors='replace')
    if maxx!=0:
      for block in iter(read_block, ''):
        ans.append(remove_digits(block))
        total += block_size
        if total >= maxx:
          break
    else:
      for block in iter(read_block, ''):
        ans.append(remove_digits(block))
  return ans


def load_data(directory: str):
  """loads lines (or blocks) from all files in directory 
  and returns a list of them"""

  examples = []
  if 'RAPTARCHIS' in directory:
    files = glob(directory+'*.pkl')
    for f in tqdm(files, desc='loading RAPTARCHIS', leave=True):
      df = pd.read_pickle(f)
      examples = df['text'].values.tolist()
      examples = [remove_digits(x) for x in examples]
  elif 'Greek-Bert' in directory:
    files = glob(directory+'europal/*')
    # files += sample(glob(directory+'oscar/*'),1)# choose a random file from oscar
    files += glob(directory+'oscar/*')
    # files += glob(directory+'wiki/*')
    block_size = 2048
    for fi in tqdm(files, desc='loading Greek-Bert', leave=True):
      examples += read_file(fi, 0)#37000000/2)
  elif 'Legal-Bert' in directory:
    # files = sample(glob(directory+'*/*/*.txt'),4500)# choose random files from oscar
    files =glob(directory+'*/*/*.txt')
    with Pool(processes=16) as pool:
      results = list(tqdm(pool.imap(read_file, files), total=len(files),
                  desc='loading Legal-Bert', leave=True))
    examples = [item for sublist in results for item in sublist]
  return examples


def load_vocab(directory):
  """ makes a vocabulary from files in directory"""
  text = load_data(directory)
  if 'RAPTARCHIS' in directory:
    limit_max = 1.0
    limit_min = 4
    name = 'RAPTARCHIS'
  elif 'Greek-Bert' in directory:
    limit_max = 1.0
    limit_min = 4
    name = 'Greek-Bert'
  elif 'Legal-Bert' in directory:
    limit_max = 1.0
    limit_min = 4
    name = 'Legal-Bert'

  count_vectorizer = CountVectorizer(min_df=limit_min, max_df=limit_max,
                          stop_words=nltk.corpus.stopwords.words('greek'), max_features=10000)
  count_vectorizer.fit(tqdm(text, desc=f'fitting vocab {name}', leave=True))
  vocab = set(tqdm(count_vectorizer.vocabulary_.keys(), desc=f'creating set {name}', leave=True))

  print(f'{name} vocab size {len(vocab)}')
  return (directory, vocab)

# %%
original_path = "/media/sf_Bert-final/"

files = original_path+"datasets/Legal-Bert/normalized/"
results1 = load_vocab(files)

files = [original_path+"datasets/RAPTARCHIS/normalized/"]
files += [original_path+"datasets/Greek-Bert/normalized/"]
with Pool(processes=8, initializer=i1) as pool:
  results2 = list(pool.imap(load_vocab, files))

results = [results1] + results2
vocabs = {}
for res in results:
  if 'Greek-Bert' in res[0]:
    key = 'Greek-Bert'
  elif 'RAPTARCHIS' in res[0]:
    key = 'RAPTARCHIS'
  elif 'Legal-Bert' in res[0]:
    key = 'Legal-Bert'
  vocabs[key] = res[1]
file_pairs = combinations(list(vocabs.keys()), 2)

overlaps = {}
for x, y in file_pairs:
  intersection = vocabs[x] & vocabs[y]
  union = (vocabs[x] | vocabs[y])
  overlaps[x + "_" + y] = len(intersection) / len(union)

print("saving overlaps...")
with open(original_path+"dont_stop_pretraining/overlaps_correct.pkl", "wb") as f:
  pickle.dump(vocabs, f)
# Out:
# loading Legal-Bert:   0%|          | 0/97928 [00:00<?, ?it/s]
# fitting vocab Legal-Bert:   0%|          | 0/2503002 [00:00<?, ?it/s]
# /home/stratigos/notebook/jupyterenv/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['δι', 'ἀλλ'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# creating set Legal-Bert:   0%|          | 0/10000 [00:00<?, ?it/s]
# Legal-Bert vocab size 10000
# loading Greek-Bert:   0%|          | 0/32 [00:00<?, ?it/s]
# loading RAPTARCHIS:   0%|          | 0/3 [00:00<?, ?it/s]
# fitting vocab RAPTARCHIS:   0%|          | 0/28536 [00:00<?, ?it/s]
# /home/stratigos/notebook/jupyterenv/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['δι', 'ἀλλ'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# creating set RAPTARCHIS:   0%|          | 0/10000 [00:00<?, ?it/s]
# RAPTARCHIS vocab size 10000
# fitting vocab Greek-Bert:   0%|          | 0/17848529 [14:47<?, ?it/s]
# creating set Greek-Bert:   0%|          | 0/10000 [00:00<?, ?it/s]
# Greek-Bert vocab size 10000
# saving overlaps...

# %%
sns.set(context="paper", style="white", font_scale=2.1, font="Times New Roman") 

z = {}
for key in overlaps.keys():
  file_1, file_2 = key.split('_')
  if not z.get(file_1):
    z[file_1] = {}
  z[file_1][file_2] = overlaps[key]
  if not z.get(file_2):
    z[file_2] = {}
  z[file_2][file_1] = overlaps[key]
labels = ["RAPTARCHIS", "Greek-Bert", "Legal-Bert"]
data = []
for ix, key in enumerate(labels):
  items = []
  for subkey in labels:
    if not z[key].get(subkey):
      items.append(1.0)
    else:
      items.append(z[key][subkey])
  data.append(items)
data = np.array(data) * 100
ax = sns.heatmap(data, cmap="Blues", vmin=5, xticklabels=labels, 
                 annot=True, fmt=".1f", cbar=False, yticklabels=labels)
plt.yticks(rotation=0)
plt.xticks(rotation=45)
plt.tight_layout()
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
