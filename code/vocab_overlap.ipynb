# %% [markdown]
# ###Vocabulary overlap
# just like in 'Don’t Stop Pretraining: Adapt Language Models to Domains and Tasks'. executed localy.

# %%
# code from https://github.com/allenai/dont-stop-pretraining slightly changed
from tqdm.notebook import tqdm
import json
from itertools import combinations
# !pip install seaborn
import seaborn as sns
import numpy as np
# !pip install --upgrade matplotlib
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
from glob import glob
from multiprocessing import Pool
import os
import re
import pandas as pd

print('Loading transformers lib...')
# !pip install transformers
from transformers import AutoTokenizer

import sys
def i1():# helper function for fork printing
  sys.stdout.write(' ')
  sys.stdout.flush()

original_path = "/media/sf_Bert-final/"
# Out:
# Requirement already satisfied: seaborn in ./jupyterenv/lib/python3.8/site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in ./jupyterenv/lib/python3.8/site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: pandas>=0.23 in ./jupyterenv/lib/python3.8/site-packages (from seaborn) (1.3.2)
# Requirement already satisfied: numpy>=1.15 in ./jupyterenv/lib/python3.8/site-packages (from seaborn) (1.21.2)
# Requirement already satisfied: scipy>=1.0 in ./jupyterenv/lib/python3.8/site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./jupyterenv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./jupyterenv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in ./jupyterenv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in ./jupyterenv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (8.3.1)
# Requirement already satisfied: cycler>=0.10 in ./jupyterenv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: six in ./jupyterenv/lib/python3.8/site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in ./jupyterenv/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2021.1)
# Requirement already satisfied: matplotlib in ./jupyterenv/lib/python3.8/site-packages (3.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in ./jupyterenv/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in ./jupyterenv/lib/python3.8/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./jupyterenv/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./jupyterenv/lib/python3.8/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in ./jupyterenv/lib/python3.8/site-packages (from matplotlib) (8.3.1)
# Requirement already satisfied: numpy>=1.16 in ./jupyterenv/lib/python3.8/site-packages (from matplotlib) (1.21.2)
# Requirement already satisfied: six in ./jupyterenv/lib/python3.8/site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Loading transformers lib...
# Requirement already satisfied: transformers in ./jupyterenv/lib/python3.8/site-packages (4.9.2)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in ./jupyterenv/lib/python3.8/site-packages (from transformers) (0.10.3)
# Requirement already satisfied: huggingface-hub==0.0.12 in ./jupyterenv/lib/python3.8/site-packages (from transformers) (0.0.12)
# Requirement already satisfied: filelock in ./jupyterenv/lib/python3.8/site-packages (from transformers) (3.0.12)
# Requirement already satisfied: packaging in ./jupyterenv/lib/python3.8/site-packages (from transformers) (21.0)
# Requirement already satisfied: sacremoses in ./jupyterenv/lib/python3.8/site-packages (from transformers) (0.0.45)
# Requirement already satisfied: tqdm>=4.27 in ./jupyterenv/lib/python3.8/site-packages (from transformers) (4.62.2)
# Requirement already satisfied: numpy>=1.17 in ./jupyterenv/lib/python3.8/site-packages (from transformers) (1.21.2)
# Requirement already satisfied: pyyaml>=5.1 in ./jupyterenv/lib/python3.8/site-packages (from transformers) (5.4.1)
# Requirement already satisfied: regex!=2019.12.17 in ./jupyterenv/lib/python3.8/site-packages (from transformers) (2021.8.21)
# Requirement already satisfied: requests in ./jupyterenv/lib/python3.8/site-packages (from transformers) (2.26.0)
# Requirement already satisfied: typing-extensions in ./jupyterenv/lib/python3.8/site-packages (from huggingface-hub==0.0.12->transformers) (3.10.0.0)
# Requirement already satisfied: pyparsing>=2.0.2 in ./jupyterenv/lib/python3.8/site-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./jupyterenv/lib/python3.8/site-packages (from requests->transformers) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in ./jupyterenv/lib/python3.8/site-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in ./jupyterenv/lib/python3.8/site-packages (from requests->transformers) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in ./jupyterenv/lib/python3.8/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: joblib in ./jupyterenv/lib/python3.8/site-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: click in ./jupyterenv/lib/python3.8/site-packages (from sacremoses->transformers) (8.0.1)
# Requirement already satisfied: six in ./jupyterenv/lib/python3.8/site-packages (from sacremoses->transformers) (1.16.0)

# %%
# dump vocabularies to txt
print('Loading Greek-Bert tokenizer...')
tokenizer = AutoTokenizer.from_pretrained("nlpaueb/bert-base-greek-uncased-v1",use_fast=True)
tokenizer.save_vocabulary(original_path+"datasets/")
os.rename(original_path+'datasets/vocab.txt', original_path+'datasets/Greek_Bert_vocab.txt')
# print('Loading Legal-Bert tokenizer...')
# tokenizer = AutoTokenizer.from_pretrained("",use_fast=True)
# tokenizer.save_vocabulary(original_path+"datasets/")
# os.rename(original_path+'datasets/vocab.txt', original_path+'datasets/Legal_Bert_vocab.txt')
print('Loading M-Bert tokenizer...')
tokenizer = AutoTokenizer.from_pretrained("bert-base-multilingual-uncased",use_fast=True)
tokenizer.save_vocabulary(original_path+"datasets/")
os.rename(original_path+'datasets/vocab.txt', original_path+'datasets/M_Bert_vocab.txt')
# Out:
# Loading Greek-Bert tokenizer...
# Loading M-Bert tokenizer...

# %%
def only_greek(vocab):
  """ findes greek words in vocab
  code from http://juditacs.github.io/2019/02/19/bert-tokenization-stats.html
  and https://github.com/juditacs/snippets/tree/master/deep_learning/bert_vocab_stats"""

  # from /unicode_ranges.txt
  # 0370	03FF	Greek/Coptic
  # 1F00	1FFF	Greek Extended
  unicode_ranges = {'Greek/Coptic': (int('0370',16),int('03FF',16)),
                    'Greek Extended': (int('1F00',16),int('1FFF',16))}

  def create_macro_regex(macro_range, include_digits=True):
      char_ranges = []
      for category in macro_range:
          start = unicode_ranges[category][0]
          end = unicode_ranges[category][1]
          char_ranges.append(r'\U{0:08x}-\U{1:08x}'.format(start, end))
      if include_digits:
          return re.compile(r'^(##)?([{0}]+[\d{0}]*)|([\d{0}]*[{0}]+)$'.format(''.join(char_ranges)))
      return re.compile(r'^(##)?[{}]+$'.format(''.join(char_ranges)))

  ans = pd.Series(vocab).str.match(create_macro_regex(['Greek/Coptic', 'Greek Extended']))
  new = [vocab[i] for i, a in enumerate(ans) if a == True]
  return new

def load_vocab(directory):
  """ loads vocabulary """
  vocab = []
  with open(directory) as f:
    for line in f:
      vocab.append(line)
  print(f'{directory[-20:]} vocab size {len(vocab)}')
  if 'M_Bert' in directory:
    vocab = only_greek(vocab)
    print(f'{directory[-20:]} Greek vocab size {len(vocab)}')
  return (directory, set(vocab))

# %%
files = glob(original_path+"datasets/*.txt")

with Pool(processes=3, initializer=i1) as pool:
  results = list(tqdm(pool.imap(load_vocab, files), total=len(files),
               desc='making vocabularies', leave=True))
vocabs = {}
for res in results:
  if 'Greek_Bert' in res[0]:
    key = 'Greek-Bert'
  elif 'Legal_Bert' in res[0]:
    key = 'Legal-Bert'
  elif 'M_Bert' in res[0]:
    key = 'M-Bert'
  vocabs[key] = res[1]
file_pairs = combinations(list(vocabs.keys()), 2)

overlaps = {}
for x, y in file_pairs:
  intersection = vocabs[x] & vocabs[y]
  union = (vocabs[x] | vocabs[y])
  #print(x, y)
  #print(len(intersection) , len(union))
  overlaps[x + "_" + y] = len(intersection) / len(union)

# print("saving overlaps...")
# with open(original_path+"dont_stop_pretraining/vocab_overlaps.json", "w+") as f:
#   json.dump(overlaps, f)
# Out:
#    Legal_Bert_vocab.txt vocab size 35100Greek_Bert_vocab.txt vocab size 35000
# making vocabularies:   0%|          | 0/3 [00:00<?, ?it/s]
# ets/M_Bert_vocab.txt vocab size 105879
# ets/M_Bert_vocab.txt Greek vocab size 1214

# %%
sns.set(context="paper", style="white", font_scale=2.1, font="Times New Roman")

z = {}
for key in overlaps.keys():
  file_1, file_2 = key.split('_')
  if not z.get(file_1):
    z[file_1] = {}
  z[file_1][file_2] = overlaps[key]
  if not z.get(file_2):
    z[file_2] = {}
  z[file_2][file_1] = overlaps[key]
labels = ["Legal-Bert", "Greek-Bert", "M-Bert"]
data = []
for ix, key in enumerate(labels):
  items = []
  for subkey in labels:
    if not z[key].get(subkey):
      items.append(1.0)
    else:
      items.append(z[key][subkey])
  data.append(items)
data = np.array(data) * 100
ax = sns.heatmap(data, cmap="Blues", vmin=5, xticklabels=labels,
                 annot=True, fmt=".1f", cbar=False, yticklabels=labels)
plt.yticks(rotation=0)
plt.xticks(rotation=45)
plt.tight_layout()
